# %%
import re

import torch
import pandas as pd

from transformers import MarkupLMFeatureExtractor
from transformers import AutoProcessor, AutoModelForSequenceClassification

# %%
def filter_p_tags(node_xpath_pairs, max_length=30):
    filtered_pairs = []
    for idx, pair in enumerate(node_xpath_pairs):
#         last_two_tags = "/".join(pair[1].rsplit("/", 2)[1:])
#         print(last_two_tags)
#         if 'body' in last_two_tags and 'p' in last_two_tags and not 'table' in last_two_tags:
        if 'body' in pair[1] and 'p' in pair[1] and not 'table' in pair[1]:
            node_text = pair[0]
            
            if len(node_text.split()) <= max_length:
                filtered_pairs.append((*pair, f"idx={idx}"))

    return filtered_pairs


def get_text_tag(node_xpath_pairs, text):
    matches = []
    for idx, pair in enumerate(node_xpath_pairs):
        if re.search(fr"{text}", pair[0].lower()):
            matches.append((*pair, f"idx={idx}"))

    return matches

def get_table_tags(node_xpath_pairs):
    filtered_pairs = []
    for idx, pair in enumerate(node_xpath_pairs):
        last_five_tags = "/".join(pair[1].rsplit("/", 5)[1:])
        
        if 'table' in last_five_tags:
            filtered_pairs.append((*pair, f"idx={idx}"))

    return filtered_pairs
    


def get_div_tags(node_xpath_pairs):
    filtered_pairs = []
    for idx, pair in enumerate(node_xpath_pairs):
        last_five_tags = "/".join(pair[1].rsplit("/", 5)[1:])
        
        if 'div' in last_five_tags:
            filtered_pairs.append((*pair, f"idx={idx}"))

    return filtered_pairs

# %%
# Sukrit's input

# input_html_filelist = [
#     "/Users/sukritrao/Documents/NYU/Coursework/Spring2023/Independent-Study/project/playground/alaska_project8.htm",
#     "/Users/sukritrao/Documents/NYU/Coursework/Spring2023/Independent-Study/project/playground/Community Bankers Trust Corporation_United Bankshares, Inc.htm",
#     "/Users/sukritrao/Documents/NYU/Coursework/Spring2023/Independent-Study/project/playground/County Bancorp, Inc._Nicolet Bankshares, Inc.html",
#     "/Users/sukritrao/Documents/NYU/Coursework/Spring2023/Independent-Study/project/playground/Perspecta Inc._Veritas Capital.htm",
#     "/Users/sukritrao/Documents/NYU/Coursework/Spring2023/Independent-Study/project/playground/MTS Systems Corporation_Amphenol Corporation.htm",
#     "/Users/sukritrao/Documents/NYU/Coursework/Spring2023/Independent-Study/project/playground/Select_Bancorp_Inc_First_Bancorp.htm"
# ]

# %%
# Rohith's input

input_html_filelist = ['./alaska_project8.htm', 
                       './glacier_altabancorp.html', 
                       './open_zix.html', 
                       './california_pacific.html', 
                       './ready_anworth.htm']

# %%
file_idx = 0
input_html = input_html_filelist[file_idx]
with open(input_html) as f:
    html_code = f.read()
    
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)

feature_extractor = MarkupLMFeatureExtractor()
encoding = feature_extractor(html_code)
# Out:
# Using device: cpu

# %%
start_node_idx = 0
end_node_idx = 400

nodes = encoding['nodes'][0][start_node_idx:end_node_idx]
xpaths = encoding['xpaths'][0][start_node_idx:end_node_idx]
important_nodes = []
possible_text_starts = ['TABLE OF CONTENTS', 'TOC', 'TABLE OF CONTENT']
possible_text_ends = ['AGREEMENT AND PLAN OF MERGER', 'PLAN AND AGREEMENT OF MERGER', 'AGREEMENT AND PLAN OF REORGANIZATION']
possible_xpath_starts = ['table', 'table[1]', 'table[2]', 'table[3]'] # Modify code to allow for any number of tables before end value
possible_xpath_ends = []
text_types = ['section_title', 'paragraph', 'table', 'other']

def table_in_xpath(xpath):
    S1, S2 = set(possible_xpath_starts), set(xpath)
    return len(S1.intersection(S2)) > 0


print("###################################################")
started = False
ended = False
xpath_lists = [path.split('/')[-7:] for path in xpaths]
start = [0, '', '']
end = [0, '', '']
section_titles = []
for i in range(len(xpath_lists)):
    text = nodes[i].strip()
    xpath_list = xpath_lists[i]
    xpath_str = xpaths[i]

    if not started:
        if (text in possible_text_starts) or table_in_xpath(xpath_list): 
            print(i)
            print(f'Possible START at Node {i}: ', text, xpath_list)
            started = True
            start = [i, text, xpath_list]

    elif started and not ended:

#         if 'table' in xpath_list:
#             print(nodes[i], xpath_lists[i])
        if (text in possible_text_ends):
            print(i)
            print(f'Possible END at Node {i}: ', text, xpath_list)
            ended = True
            end = [i, text, xpath_list]
            
    
print("###################################################")
# Out:
# ###################################################
# 13
# Possible START at Node 13:  TABLE OF CONTENTS ['filename', 'description', 'text', 'html', 'body', 'p[18]', 'b']
# 345
# Possible END at Node 345:  AGREEMENT AND PLAN OF MERGER ['filename', 'description', 'text', 'html', 'body', 'p[33]', 'b']
# ###################################################

# %%
# Extracts all paths and nodes within TOC boundaries
toc_paths = xpaths[start[0] + (0 if 'table' in start[2] else 1):end[0]-1]
toc_nodes = nodes[start[0] + (0 if 'table' in start[2] else 1):end[0]-1]

# %%
toc_nodes[0:10]
# Out:
# ['Page',
#  'ARTICLE 1',
#  'DEFINITIONS',
#  '1',
#  'Section 1.01',
#  'Definitions',
#  '1',
#  'Section 1.02',
#  'Other Definitional and Interpretative Provisions',
#  '16']

# %%
# Using regex to find table tag and splitting on the table tag

# Change index() to find() if exceptions become an issue
# TODO: Automate finding table tag instead of hardcoding for indexing
reg_str = r'table(\[[0-9]+\])?'
table_end_idx = re.search(reg_str, toc_paths[0]).span()[0]
TOC_root_str = toc_paths[0][:table_end_idx]

shortened_toc_paths = [path[table_end_idx:].split('/') for path in toc_paths]
shortened_toc_paths[:10]

toc_paths_full = []
for i in range(len(toc_paths)):
    full_paths_nodes = [toc_nodes[i], toc_paths[i]] + shortened_toc_paths[i]
    
        
    toc_paths_full.append(full_paths_nodes)
# group_list = [path.index('1') for path in shortened_toc_paths]
# group_list[:5]


# After extracting TOC, then use get_text_tag to match to section title in document

# %%
full_paths_df = pd.DataFrame(toc_paths_full).rename(columns={0 : "node_text", 1 : "full_xpath", 2 : "table", 3 : "tr", 4 : "td"})

# %%
sorted_df = full_paths_df.sort_values(by=['table', 'tr'], axis=0)
sorted_df.iloc[99:120]
# Out:
#                                              node_text  \
# 122                                       Section 4.23
# 123                                      Brokers’ Fees
# 124                                                 48
# 125                                       Section 4.24
# 126                       Opinion of Financial Advisor
# 127                                                 48
# 128                                       Section 4.25
# 129                                    Trade Practices
# 130                                                 49
# 131                                       Section 4.26
# 132                           International Trade Laws
# 133                                                 49
# 134                                       Section 4.27
# 135                    Macquarie/GCM Merger Agreement.
# 136                                                 49
# 137                                          ARTICLE 5
# 138  REPRESENTATIONS AND WARRANTIES OF PARENT AND M...
# 139                                                 50
# 140                                       Section 5.01
# 141                   Organization, Standing and Power
# 142                                                 50
#
#                                             full_xpath     table      tr  \
# 122  /document/type/sequence/filename/description/t...  table[2]  tr[12]
# 123  /document/type/sequence/filename/description/t...  table[2]  tr[12]
# 124  /document/type/sequence/filename/description/t...  table[2]  tr[12]
# 125  /document/type/sequence/filename/description/t...  table[2]  tr[13]
# 126  /document/type/sequence/filename/description/t...  table[2]  tr[13]
# 127  /document/type/sequence/filename/description/t...  table[2]  tr[13]
# 128  /document/type/sequence/filename/description/t...  table[2]  tr[14]
# 129  /document/type/sequence/filename/description/t...  table[2]  tr[14]
# 130  /document/type/sequence/filename/description/t...  table[2]  tr[14]
# 131  /document/type/sequence/filename/description/t...  table[2]  tr[15]
# 132  /document/type/sequence/filename/description/t...  table[2]  tr[15]
# 133  /document/type/sequence/filename/description/t...  table[2]  tr[15]
# 134  /document/type/sequence/filename/description/t...  table[2]  tr[16]
# 135  /document/type/sequence/filename/description/t...  table[2]  tr[16]
# 136  /document/type/sequence/filename/description/t...  table[2]  tr[16]
# 137  /document/type/sequence/filename/description/t...  table[2]  tr[17]
# 138  /document/type/sequence/filename/description/t...  table[2]  tr[17]
# 139  /document/type/sequence/filename/description/t...  table[2]  tr[17]
# 140  /document/type/sequence/filename/description/t...  table[2]  tr[18]
# 141  /document/type/sequence/filename/description/t...  table[2]  tr[18]
# 142  /document/type/sequence/filename/description/t...  table[2]  tr[18]
#
#         td  5     6
# 122  td[1]  p  None
# 123  td[2]  p  None
# 124  td[3]  p  None
# 125  td[1]  p  None
# 126  td[2]  p  None
# 127  td[3]  p  None
# 128  td[1]  p  None
# 129  td[2]  p  None
# 130  td[3]  p  None
# 131  td[1]  p  None
# 132  td[2]  p  None
# 133  td[3]  p  None
# 134  td[1]  p  None
# 135  td[2]  p  None
# 136  td[3]  p  None
# 137  td[1]  p     b
# 138  td[1]  p  None
# 139  td[2]  p  None
# 140  td[1]  p  None
# 141  td[2]  p  None
# 142  td[3]  p  None

# %%
grouped_df = full_paths_df.groupby(by=['table', 'tr'], axis=0)
def combine_rows(x):
    return pd.Series({'node_text': ' '.join(x['node_text']), 'full_xpath': x.iloc[0]['full_xpath']})
concat_text_df = grouped_df.apply(combine_rows)
concat_text_df = concat_text_df.reset_index(drop=False).sort_values(by=['table', 'tr'])
concat_text_df['tr_idx'] = concat_text_df['tr'].apply(lambda x: int(x[3:-1]) if 'div' not in x else -999)
concat_text_df['table_idx'] = concat_text_df['table'].apply(lambda x: int(x[6:-1]) if 'div' not in x else -999)
concat_text_df = concat_text_df.sort_values(by=['table_idx', 'tr_idx']).drop(columns=['tr_idx', 'table_idx'])
concat_text_df.to_csv('toc_node_xpath_pairs.csv')

# %%
full_paths_df
# Out:
#                                              node_text  \
# 0                                                 Page
# 1                                            ARTICLE 1
# 2                                          DEFINITIONS
# 3                                                    1
# 4                                         Section 1.01
# ..                                                 ...
# 325                                       Section 9.17
# 326                                     Transfer Taxes
# 327                                                 91
# 328  Exhibit A – Form of Certificate of Incorporati...
# 329  Exhibit B – Form of Bylaws of the Surviving Co...
#
#                                             full_xpath     table      tr  \
# 0    /document/type/sequence/filename/description/t...  table[1]   tr[1]
# 1    /document/type/sequence/filename/description/t...  table[1]   tr[3]
# 2    /document/type/sequence/filename/description/t...  table[1]   tr[3]
# 3    /document/type/sequence/filename/description/t...  table[1]   tr[3]
# 4    /document/type/sequence/filename/description/t...  table[1]   tr[4]
# ..                                                 ...       ...     ...
# 325  /document/type/sequence/filename/description/t...  table[4]  tr[15]
# 326  /document/type/sequence/filename/description/t...  table[4]  tr[15]
# 327  /document/type/sequence/filename/description/t...  table[4]  tr[15]
# 328  /document/type/sequence/filename/description/t...     p[28]    None
# 329  /document/type/sequence/filename/description/t...     p[30]    None
#
#         td     5     6
# 0    td[3]     b  None
# 1    td[1]     p     b
# 2    td[1]     p  None
# 3    td[2]     p  None
# 4    td[1]     p  None
# ..     ...   ...   ...
# 325  td[1]     p  None
# 326  td[2]     p  None
# 327  td[3]     p  None
# 328   None  None  None
# 329   None  None  None
#
# [330 rows x 7 columns]

# %% [markdown]
# Main idea for classifying text into our (currently 4) labels: section titles, paragraphs, tables, or other. The code first detects the boundaries of the TOC for future reference in identifying section titles.
#
# #### TOC Extraction
# Here we extract out each section title. We can conveniently group by the tr, or table row, xpath value to get each line in the TOC. We then split and join based on the td, data cell, tag to get the full section title and corresponding page number. We can use this page number when finding the section titles.
#
# #### Section Titles
# We first run through lines of the merger and detect or group by(pd groupby?) those elements which are in the same p tag, or div tag. If the lines grouped together match a section title which we extracted from the TOC, then it can be considered a label for the title.
#
# #### Paragraph Tags
# We follow the same grouping procedure as for titles. We know each title should theoretically have corresponding paragraphs. We locate each section title and track all text in p tags underneath as a paragraph until the next section title.

# %%
# TOC Extraction

xpaths[14:34]
# Out:
# ['/document/type/sequence/filename/description/text/html/body/p/center/div/table/tr[3]/td[1]/p',
#  '/document/type/sequence/filename/description/text/html/body/p/center/div/table/tr[3]/td[4]',
#  '/document/type/sequence/filename/description/text/html/body/p/center/div/table/tr[4]/td[1]/p',
#  '/document/type/sequence/filename/description/text/html/body/p/center/div/table/tr[4]/td[3]',
#  '/document/type/sequence/filename/description/text/html/body/p/center/div/table/tr[4]/td[6]',
#  '/document/type/sequence/filename/description/text/html/body/p/center/div/table/tr[5]/td[1]/p',
#  '/document/type/sequence/filename/description/text/html/body/p/center/div/table/tr[5]/td[3]',
#  '/document/type/sequence/filename/description/text/html/body/p/center/div/table/tr[5]/td[6]',
#  '/document/type/sequence/filename/description/text/html/body/p/center/div/table/tr[6]/td[1]/p',
#  '/document/type/sequence/filename/description/text/html/body/p/center/div/table/tr[6]/td[3]',
#  '/document/type/sequence/filename/description/text/html/body/p/center/div/table/tr[6]/td[6]',
#  '/document/type/sequence/filename/description/text/html/body/p/center/div/table/tr[7]/td[1]/p',
#  '/document/type/sequence/filename/description/text/html/body/p/center/div/table/tr[7]/td[3]',
#  '/document/type/sequence/filename/description/text/html/body/p/center/div/table/tr[7]/td[6]',
#  '/document/type/sequence/filename/description/text/html/body/p/center/div/table/tr[8]/td[1]/p',
#  '/document/type/sequence/filename/description/text/html/body/p/center/div/table/tr[8]/td[4]',
#  '/document/type/sequence/filename/description/text/html/body/p/center/div/table/tr[9]/td[1]/p',
#  '/document/type/sequence/filename/description/text/html/body/p/center/div/table/tr[9]/td[3]',
#  '/document/type/sequence/filename/description/text/html/body/p/center/div/table/tr[9]/td[6]',
#  '/document/type/sequence/filename/description/text/html/body/p/center/div/table/tr[10]/td[1]/p']

# %%
nodes = encoding['nodes'][0]
xpaths = encoding['xpaths'][0]

# cropped_xpaths = ["/".join(x.rsplit("/", 5)[1:]) for x in xpaths]

# node_xpath_pairs = list(zip(nodes, cropped_xpaths))
node_xpath_pairs = list(zip(nodes, xpaths))

# %%
for x in node_xpath_pairs[376:382]:
    print(x, '\n')
# Out:
# ('”) to commence a cash tender offer (as it may be amended from time to time as permitted under this Agreement, the “', '/document/type/sequence/filename/description/text/html/body/p/p/p/p/center/div/p[4]')
#
# ('Offer', '/document/type/sequence/filename/description/text/html/body/p/p/p/p/center/div/p[4]/b[2]/i')
#
# ('”) to purchase\nany and all of the outstanding shares of the Company Common Stock (the “', '/document/type/sequence/filename/description/text/html/body/p/p/p/p/center/div/p[4]')
#
# ('Shares', '/document/type/sequence/filename/description/text/html/body/p/p/p/p/center/div/p[4]/b[3]/i')
#
# ('”), at a price per Share of $8.50, without interest and subject to any applicable withholding Taxes (such amount, or any higher amount per share\nthat may be paid pursuant to the Offer, the “', '/document/type/sequence/filename/description/text/html/body/p/p/p/p/center/div/p[4]')
#
# ('Offer Price', '/document/type/sequence/filename/description/text/html/body/p/p/p/p/center/div/p[4]/b[4]/i')

# %%
raw = []
for i in node_xpath_pairs:
    path_list = i[1].split('/')
    if len(path_list) > 9 and path_list[9][:5] == 'table':
        l = [i[0]] + path_list[9:12]
        raw.append(l)

# %%
df = pd.DataFrame(raw)
df.columns = ['text', 'table', 'tr', 'td']
df.to_csv('raw.csv')

# %%
# Create function for merging mutiple xpath node pairs in a list
new_paths = []
table = [raw[0][1], [[raw[0][0], raw[0][2], raw[0][3]]]]
for i in raw:
    if i[1] != table[0]:
        new_paths.append(table)
        table = [i[1], [[i[0], i[2], i[3]]]]
    if i[2] != table[1][-1][1]:
        table[1].append([i[0], i[2], i[3]])
    else:
        table[1][-1][0] += (' ' + i[0])
        table[1][-1][2] = i[3]
new_paths.append(table)

import json
with open('new_path.json', 'w') as f:
    json.dump(new_paths, f)

# %%
filtered_p_tags = filter_p_tags(node_xpath_pairs)
# filtered_p_tags[2305]

# %%
new_paths
# Out:
# [['table[1]',
#   [['Page Page', 'tr[1]', 'td[3]'],
#    ['ARTICLE 1 DEFINITIONS 1', 'tr[3]', 'td[2]'],
#    ['Section 1.01 Definitions 1', 'tr[4]', 'td[3]'],
#    ['Section 1.02 Other Definitional and Interpretative Provisions 16',
#     'tr[5]',
#     'td[3]'],
#    ['ARTICLE 2 THE MERGER 17', 'tr[6]', 'td[2]'],
#    ['Section 2.01 The Closing 17', 'tr[7]', 'td[3]'],
#    ['Section 2.02 The Merger 17', 'tr[8]', 'td[3]'],
#    ['Section 2.03 Conversion of Shares 18', 'tr[9]', 'td[3]'],
#    ['Section 2.04 Exchange and Payment 18', 'tr[10]', 'td[3]'],
#    ['Section 2.05 Dissenting Shares 20', 'tr[11]', 'td[3]'],
#    ['Section 2.06 Company Equity Awards; ESPP 20', 'tr[12]', 'td[3]'],
#    ['Section 2.07 Adjustments 23', 'tr[13]', 'td[3]'],
#    ['Section 2.08 Withholding Rights 23', 'tr[14]', 'td[3]'],
#    ['Section 2.09 Termination of Macquarie/GCM Merger Agreement and Payment of Termination Fee 23',
#     'tr[15]',
#     'td[3]'],
#    ['ARTICLE 3 THE SURVIVING CORPORATION 23', 'tr[16]', 'td[2]'],
#    ['Section 3.01 Certificate of Incorporation 23', 'tr[17]', 'td[3]'],
#    ['Section 3.02 Bylaws 24', 'tr[18]', 'td[3]'],
#    ['Section 3.03 Directors and Officers 24', 'tr[19]', 'td[3]'],
#    ['ARTICLE 4 REPRESENTATIONS AND WARRANTIES OF THE COMPANY 24',
#     'tr[20]',
#     'td[2]'],
#    ['Section 4.01 Organization, Standing and Power 24', 'tr[21]', 'td[3]'],
#    ['Section 4.02 Corporate Authorization 25', 'tr[22]', 'td[3]'],
#    ['Section 4.03 Governmental Authorization 25', 'tr[23]', 'td[3]'],
#    ['Section 4.04 Non-contravention 26', 'tr[24]', 'td[3]'],
#    ['Section 4.05 Capitalization 26', 'tr[25]', 'td[3]'],
#    ['Section 4.06 Subsidiaries 28', 'tr[26]', 'td[3]'],
#    ['Section 4.07 SEC Filings and the Sarbanes-Oxley Act 28',
#     'tr[27]',
#     'td[3]'],
#    ['Section 4.08 Financial Statements; Internal Controls 30',
#     'tr[28]',
#     'td[3]'],
#    ['Section 4.09 Absence of Certain Changes 31', 'tr[29]', 'td[3]'],
#    ['Section 4.10 No Undisclosed Material Liabilities 31', 'tr[30]', 'td[3]'],
#    ['Section 4.11 Litigation 31', 'tr[31]', 'td[3]']]],
#  ['table[2]',
#   [['Section 4.12 Section 4.12 Compliance with Applicable Law; Licenses 32',
#     'tr[1]',
#     'td[3]'],
#    ['Section 4.13 Certain Business Practices 34', 'tr[2]', 'td[3]'],
#    ['Section 4.14 Material Contracts 34', 'tr[3]', 'td[3]'],
#    ['Section 4.15 Taxes 37', 'tr[4]', 'td[3]'],
#    ['Section 4.16 Employee Benefit Plans 38', 'tr[5]', 'td[3]'],
#    ['Section 4.17 Labor and Employment Matters 42', 'tr[6]', 'td[3]'],
#    ['Section 4.18 Insurance 43', 'tr[7]', 'td[3]'],
#    ['Section 4.19 Environmental Matters 43', 'tr[8]', 'td[3]'],
#    ['Section 4.20 Intellectual Property 44', 'tr[9]', 'td[3]'],
#    ['Section 4.21 Properties 46', 'tr[10]', 'td[3]'],
#    ['Section 4.22 Privacy and Data Security 47', 'tr[11]', 'td[3]'],
#    ['Section 4.23 Brokers’\xa0Fees 48', 'tr[12]', 'td[3]'],
#    ['Section 4.24 Opinion of Financial Advisor 48', 'tr[13]', 'td[3]'],
#    ['Section 4.25 Trade Practices 49', 'tr[14]', 'td[3]'],
#    ['Section 4.26 International Trade Laws 49', 'tr[15]', 'td[3]'],
#    ['Section 4.27 Macquarie/GCM Merger Agreement. 49', 'tr[16]', 'td[3]'],
#    ['ARTICLE 5 REPRESENTATIONS AND WARRANTIES OF PARENT AND MERGER SUB 50',
#     'tr[17]',
#     'td[2]'],
#    ['Section 5.01 Organization, Standing and Power 50', 'tr[18]', 'td[3]'],
#    ['Section 5.02 Corporate Authorization 50', 'tr[19]', 'td[3]'],
#    ['Section 5.03 Governmental Authorization 50', 'tr[20]', 'td[3]'],
#    ['Section 5.04 Non-contravention 50', 'tr[21]', 'td[3]'],
#    ['Section 5.05 Capitalization and Operation of Merger Sub 51',
#     'tr[22]',
#     'td[3]'],
#    ['Section 5.06 No Vote of Parent Stockholders; Required Approval 51',
#     'tr[23]',
#     'td[3]'],
#    ['Section 5.07 Litigation 51', 'tr[24]', 'td[3]'],
#    ['Section 5.08 Financing 52', 'tr[25]', 'td[3]'],
#    ['Section 5.09 Solvency 53', 'tr[26]', 'td[3]'],
#    ['Section 5.10 Guarantees 53', 'tr[27]', 'td[3]'],
#    ['Section 5.11 Absence of Certain Agreements 53', 'tr[28]', 'td[3]'],
#    ['Section 5.12 Stock Ownership 54', 'tr[29]', 'td[3]'],
#    ['Section 5.13 Equity Investors 54', 'tr[30]', 'td[3]'],
#    ['ARTICLE 6 COVENANTS 54', 'tr[31]', 'td[2]'],
#    ['Section 6.01 Conduct of the Company 54', 'tr[32]', 'td[3]']]],
#  ['table[3]',
#   [['Section 6.02 Section 6.02 No Solicitation 58', 'tr[1]', 'td[3]'],
#    ['Section 6.03 Company Recommendation 60', 'tr[2]', 'td[3]'],
#    ['Section 6.04 Preparation of Proxy Statement; Stockholders’\xa0Meeting 63',
#     'tr[3]',
#     'td[3]'],
#    ['Section 6.05 Access to Information 64', 'tr[4]', 'td[3]'],
#    ['Section 6.06 Notice of Certain Events 65', 'tr[5]', 'td[3]'],
#    ['Section 6.07 Employee Benefit Plan Matters 65', 'tr[6]', 'td[3]'],
#    ['Section 6.08 State Takeover Laws 67', 'tr[7]', 'td[3]'],
#    ['Section 6.09 Obligations of Merger Sub 67', 'tr[8]', 'td[3]'],
#    ['Section 6.10 Voting of Shares 67', 'tr[9]', 'td[3]'],
#    ['Section 6.11 Director and Officer Indemnification, Exculpation and Insurance 68',
#     'tr[10]',
#     'td[3]'],
#    ['Section 6.12 Further Action; Regulatory Approvals; Reasonable Best Efforts 69',
#     'tr[11]',
#     'td[3]'],
#    ['Section 6.13 Stockholder Litigation 72', 'tr[12]', 'td[3]'],
#    ['Section 6.14 Public Announcements 72', 'tr[13]', 'td[3]'],
#    ['Section 6.15 Further Assurances 73', 'tr[14]', 'td[3]'],
#    ['Section 6.16 Section 16 Matters 73', 'tr[15]', 'td[3]'],
#    ['Section 6.17 Financing 74', 'tr[16]', 'td[3]'],
#    ['Section 6.18 Confidentiality 76', 'tr[17]', 'td[3]'],
#    ['Section 6.19 Director Resignations 77', 'tr[18]', 'td[3]'],
#    ['Section 6.20 Merger Sub Expenditure; Parent Distributions 77',
#     'tr[19]',
#     'td[3]'],
#    ['Section 6.21 Stock Market De-Listing 77', 'tr[20]', 'td[3]'],
#    ['Section 6.22 Standstill 78', 'tr[21]', 'td[3]'],
#    ['ARTICLE 7 CONDITIONS TO THE MERGER 78', 'tr[22]', 'td[2]'],
#    ['Section 7.01 Conditions to the Obligations of Each Party 78',
#     'tr[23]',
#     'td[3]'],
#    ['Section 7.02 Conditions to the Obligations of Parent and Merger Sub 79',
#     'tr[24]',
#     'td[3]'],
#    ['Section 7.03 Conditions to the Obligations of the Company 80',
#     'tr[25]',
#     'td[3]'],
#    ['Section 7.04 Frustration of Closing Conditions 80', 'tr[26]', 'td[3]'],
#    ['ARTICLE 8 TERMINATION 80', 'tr[27]', 'td[2]'],
#    ['Section 8.01 Termination 80', 'tr[28]', 'td[3]'],
#    ['Section 8.02 Effect of Termination 82', 'tr[29]', 'td[3]'],
#    ['ARTICLE 9 MISCELLANEOUS 82', 'tr[30]', 'td[2]'],
#    ['Section 9.01 Notices 82', 'tr[31]', 'td[3]'],
#    ['Section 9.02 Nonsurvival of Representations and Warranties 83',
#     'tr[32]',
#     'td[3]']]],
#  ['table[4]',
#   [['Section 9.03 Section 9.03 Amendments and Waivers 83', 'tr[1]', 'td[3]'],
#    ['Section 9.04 Fees and Expenses 84', 'tr[2]', 'td[3]'],
#    ['Section 9.05 Assignment; Benefit 86', 'tr[3]', 'td[3]'],
#    ['Section 9.06 Governing Law 86', 'tr[4]', 'td[3]'],
#    ['Section 9.07 Jurisdiction 86', 'tr[5]', 'td[3]'],
#    ['Section 9.08 Waiver of Jury Trial 86', 'tr[6]', 'td[3]'],
#    ['Section 9.09 Specific Performance 87', 'tr[7]', 'td[3]'],
#    ['Section 9.10 Severability 88', 'tr[8]', 'td[3]'],
#    ['Section 9.11 Parent Guarantee 88', 'tr[9]', 'td[3]'],
#    ['Section 9.12 Entire Agreement; No Reliance; Access to Information 88',
#     'tr[10]',
#     'td[3]'],
#    ['Section 9.13 No Presumption Against Drafting Party 89',
#     'tr[11]',
#     'td[3]'],
#    ['Section 9.14 Counterparts; Effectiveness 90', 'tr[12]', 'td[3]'],
#    ['Section 9.15 Debt Financing Matters 90', 'tr[13]', 'td[3]'],
#    ['Section 9.16 Limitation on Recourse 91', 'tr[14]', 'td[3]'],
#    ['Section 9.17 Transfer Taxes 91', 'tr[15]', 'td[3]']]],
#  ['table[5]',
#   [['Term Term Section', 'tr[1]', 'td[2]'],
#    ['Adverse Recommendation Change 6.03(a)', 'tr[2]', 'td[2]'],
#    ['Agreement Preamble', 'tr[3]', 'td[2]'],
#    ['Alternative Debt Financing 6.17(f)', 'tr[4]', 'td[2]'],
#    ['Capitalization Date 4.05(a)', 'tr[5]', 'td[2]'],
#    ['Cash Award Payments 6.07(e)', 'tr[6]', 'td[2]'],
#    ['Certificate of Merger 2.02(a)', 'tr[7]', 'td[2]'],
#    ['Certificates 2.04(a)', 'tr[8]', 'td[2]'],
#    ['Closing 2.01', 'tr[9]', 'td[2]'],
#    ['COBRA 4.16(k)', 'tr[10]', 'td[2]'],
#    ['Communications Act 4.03', 'tr[11]', 'td[2]'],
#    ['Communications Consents 7.01(d)', 'tr[12]', 'td[2]'],
#    ['Company Preamble', 'tr[13]', 'td[2]']]],
#  ['table[6]',
#   [['Term Term Section', 'tr[1]', 'td[2]'],
#    ['Company Common Stock 4.05(a)', 'tr[2]', 'td[2]'],
#    ['Company Communications Licenses 4.12(c)', 'tr[3]', 'td[2]'],
#    ['Company FCC Licenses 4.12(c)', 'tr[4]', 'td[2]'],
#    ['Company Preferred Stock 4.05(a)', 'tr[5]', 'td[2]'],
#    ['Company Recommendation 4.02(b)', 'tr[6]', 'td[2]'],
#    ['Company Recovery Costs 9.04(c)', 'tr[7]', 'td[2]'],
#    ['Company Registrations 4.20(a)', 'tr[8]', 'td[2]'],
#    ['Company Related Parties 9.04(b)', 'tr[9]', 'td[2]'],
#    ['Company SEC Documents Article 4', 'tr[10]', 'td[2]'],
#    ['Company Securities 4.05(c)', 'tr[11]', 'td[2]'],
#    ['Company State Licenses 4.12(c)', 'tr[12]', 'td[2]'],
#    ['Confidentiality Agreement 6.18', 'tr[13]', 'td[2]'],
#    ['Continuing Employees 6.07(a)', 'tr[14]', 'td[2]'],
#    ['Current Premium 6.11(a)', 'tr[15]', 'td[2]'],
#    ['Debt Financing 6.17(a)', 'tr[16]', 'td[2]'],
#    ['Debt Financing Commitment Letter 5.08', 'tr[17]', 'td[2]'],
#    ['Deferred Stock Award Payments 2.06(c)', 'tr[18]', 'td[2]'],
#    ['DGCL Recitals', 'tr[19]', 'td[2]'],
#    ['DOJ 6.12(b)', 'tr[20]', 'td[2]'],
#    ['Effective Time 2.02(b)', 'tr[21]', 'td[2]'],
#    ['End Date 8.01(b)', 'tr[22]', 'td[2]'],
#    ['Equity Commitment Letters Recitals', 'tr[23]', 'td[2]'],
#    ['Equity Financing 5.08', 'tr[24]', 'td[2]'],
#    ['Equity Investors Recitals', 'tr[25]', 'td[2]'],
#    ['Exchange Agent 2.04(a)', 'tr[26]', 'td[2]'],
#    ['Excluded Benefits 6.07(a)', 'tr[27]', 'td[2]'],
#    ['FAA 4.12(d)', 'tr[28]', 'td[2]'],
#    ['FAA Rules 4.12(h)', 'tr[29]', 'td[2]'],
#    ['FCC 4.03', 'tr[30]', 'td[2]'],
#    ['FCC Rules 4.03', 'tr[31]', 'td[2]'],
#    ['Final Exercise Date 2.06(d)', 'tr[32]', 'td[2]'],
#    ['Financing Commitment Letters 5.08', 'tr[33]', 'td[2]'],
#    ['FTC 6.12(b)', 'tr[34]', 'td[2]'],
#    ['Guarantees Recitals', 'tr[35]', 'td[2]'],
#    ['Guarantor Recitals', 'tr[36]', 'td[2]'],
#    ['Indemnified Party 6.11(b)', 'tr[37]', 'td[2]'],
#    ['Insurance Policies 4.18', 'tr[38]', 'td[2]'],
#    ['Investor Entities 5.12', 'tr[39]', 'td[2]'],
#    ['IRS 4.16(a)', 'tr[40]', 'td[2]'],
#    ['Leased Real Property 4.21', 'tr[41]', 'td[2]'],
#    ['Localities 4.03', 'tr[42]', 'td[2]'],
#    ['Locality Permits 4.12(c)', 'tr[43]', 'td[2]'],
#    ['Malicious Code 4.20(i)', 'tr[44]', 'td[2]'],
#    ['Material Contract 4.14(b)', 'tr[45]', 'td[2]'],
#    ['Merger Recitals', 'tr[46]', 'td[2]']]],
#  ['table[7]',
#   [['Term Term Section', 'tr[1]', 'td[2]'],
#    ['Merger Consideration 2.03(a)', 'tr[2]', 'td[2]'],
#    ['Merger Sub Preamble', 'tr[3]', 'td[2]'],
#    ['Multiemployer Plan 4.16(d)', 'tr[4]', 'td[2]'],
#    ['Notice of Intervening Event 6.03(b)(iii)(A)', 'tr[5]', 'td[2]'],
#    ['Notice of Superior Proposal 6.03(b)(ii)(A)', 'tr[6]', 'td[2]'],
#    ['Owned Real Property 4.21', 'tr[7]', 'td[2]'],
#    ['Parent Preamble', 'tr[8]', 'td[2]'],
#    ['Parent Benefit Plans 6.07(a)', 'tr[9]', 'td[2]'],
#    ['Parent Expenses 9.04(c)', 'tr[10]', 'td[2]'],
#    ['Parent Recovery Costs 9.04(b)', 'tr[11]', 'td[2]'],
#    ['Parent Related Parties 9.04(c)', 'tr[12]', 'td[2]'],
#    ['Payment Fund 2.04(a)', 'tr[13]', 'td[2]'],
#    ['PBGC 4.16(c)', 'tr[14]', 'td[2]'],
#    ['Pension Plan 4.16(c)', 'tr[15]', 'td[2]'],
#    ['Proxy Statement 6.04(a)', 'tr[16]', 'td[2]'],
#    ['PSU Award Payments 2.06(b)', 'tr[17]', 'td[2]'],
#    ['PUCs 4.03', 'tr[18]', 'td[2]'],
#    ['Real Property 4.21', 'tr[19]', 'td[2]'],
#    ['Remedy Actions 6.12(f)', 'tr[20]', 'td[2]'],
#    ['Required Amount 5.08', 'tr[21]', 'td[2]'],
#    ['RSU Award Payments 2.06(a)', 'tr[22]', 'td[2]'],
#    ['Solvent 5.09', 'tr[23]', 'td[2]'],
#    ['Specific Performance Conditions 9.09(a)', 'tr[24]', 'td[2]'],
#    ['Stockholder Approval 4.02(a)', 'tr[25]', 'td[2]'],
#    ['Stockholder Meeting 6.04(a)', 'tr[26]', 'td[2]'],
#    ['Superior Proposal Notice Period 6.03(b)(ii)(A)', 'tr[27]', 'td[2]'],
#    ['Surviving Corporation 2.02(c)', 'tr[28]', 'td[2]'],
#    ['Transfer Taxes 9.17', 'tr[29]', 'td[2]'],
#    ['Third Party Intellectual Property 4.20(e)', 'tr[30]', 'td[2]'],
#    ['USAC 4.12(d)', 'tr[31]', 'td[2]']]],
#  ['table[8]',
#   [['Attention: Attention: Michael T. Prior Mary Mabey', 'tr', 'td[3]']]],
#  ['table[9]',
#   [['Attention: Attention: Mitchell Presser David Slotkin', 'tr', 'td[3]']]],
#  ['table[10]',
#   [['E-Mail: E-Mail: MPresser@mofo.com ; DSlotkin@mofo.com', 'tr', 'td[3]']]],
#  ['table[11]',
#   [['ALASKA COMMUNICATIONS SYSTEMS GROUP, INC. ALASKA COMMUNICATIONS SYSTEMS GROUP, INC.',
#     'tr[1]',
#     'td[2]'],
#    ['By: /s/ William H. Bishop', 'tr[4]', 'td[2]'],
#    ['Name: William H. Bishop', 'tr[6]', 'td[2]'],
#    ['Title: President and Chief Executive Officer', 'tr[8]', 'td[2]'],
#    ['PROJECT 8 BUYER, LLC', 'tr[11]', 'td[2]'],
#    ['By: /s/ Michael T. Prior', 'tr[14]', 'td[2]'],
#    ['Name: Michael T. Prior', 'tr[16]', 'td[2]'],
#    ['Title: President', 'tr[18]', 'td[2]'],
#    ['PROJECT 8 MERGERSUB, INC.', 'tr[21]', 'td[2]'],
#    ['By: /s/ Michael T. Prior', 'tr[24]', 'td[2]'],
#    ['Name: Michael T. Prior', 'tr[26]', 'td[2]'],
#    ['Title: President', 'tr[28]', 'td[2]']]]]

# %% [markdown]
# # Alaska Project
#
# ## Section Title
# "the following terms have the following meanings", 379
#
#
# ## Signature Page
#
# in witness whereof, 2305
#
# ## Table of Contents
#
# table of contents 13

# %% [markdown]
# # Community Bankers
#
# ## Section Title
#
# "following terms are used in this agreement" 247
#
#
# ### Signature
#
# in witness, 1701

# %% [markdown]
# # Perspecta
#
# ### Section Title
# the following terms have the meanings set forth, 349
#
#
# ### Signature
#
# in witness whereof, 2809

# %%
# get_text_tag(filtered_p_tags, 'section')
# get_text_tag(get_div_tags(node_xpath_pairs), '1')

# %%
get_text_tag(node_xpath_pairs, "in witness")
# Out:
# [('IN WITNESS WHEREOF',
#   '/document/type/sequence/filename/description/text/html/body/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/center/div/p[1]/b',
#   'idx=1701'),
#  ('IN WITNESS WHEREOF, Essex Bank and United Bank have each caused this Agreement and Plan of\nMerger to be executed as of the date first above written.',
#   '/document/type/sequence/filename/description/text/html/body/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/center/div/p[1]',
#   'idx=2059'),
#  ('IN WITNESS WHEREOF, the parties hereto have caused this Agreement to be executed as of the\nday first above written.',
#   '/document/type/sequence/filename/description/text/html/body/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/p/center/div/p[1]',
#   'idx=2223')]

# %%
node_idx = 379
node_xpath_pairs[node_idx - 2 : node_idx + 10]
# Out:
# [('DEFINITIONS',
#   '/document/type/sequence/filename/description/text/html/body/p[47]'),
#  ('Section 1.01',
#   '/document/type/sequence/filename/description/text/html/body/p[49]'),
#  ('Definitions',
#   '/document/type/sequence/filename/description/text/html/body/p[49]/u'),
#  ('.', '/document/type/sequence/filename/description/text/html/body/p[49]'),
#  ('(a)\xa0\xa0\xa0\xa0As used herein, the following terms have the following meanings:',
#   '/document/type/sequence/filename/description/text/html/body/p[51]'),
#  ('“2018 Cash Award',
#   '/document/type/sequence/filename/description/text/html/body/p[54]/b'),
#  ('s” means the cash awards granted to certain employees of the Company in 2018 in lieu of any Company RSU Awards or Company PSU Awards for 2018.',
#   '/document/type/sequence/filename/description/text/html/body/p[54]'),
#  ('“Acceptable Confidentiality Agreement',
#   '/document/type/sequence/filename/description/text/html/body/p[56]/b'),
#  ('” means a confidentiality agreement (i) containing terms not materially less restrictive in the aggregate to the counterparty thereto than the terms of the Confidentiality Agreement (including with regard to any standstill obligations), and (ii) that does not restrict the Company or its Representatives from providing the information or access required to be provided to Parent pursuant to',
#   '/document/type/sequence/filename/description/text/html/body/p[56]'),
#  ('Section 6.02',
#   '/document/type/sequence/filename/description/text/html/body/p[56]/u[1]'),
#  ('and', '/document/type/sequence/filename/description/text/html/body/p[56]'),
#  ('Section 6.03',
#   '/document/type/sequence/filename/description/text/html/body/p[56]/u[2]')]

# %% [markdown]
# ## DJANGO

# %%
from django.template import Template, Context
from django.conf import settings
 # We have to do this to use django templates standalone - see
# http://stackoverflow.com/questions/98135/how-do-i-use-django-templates-without-the-rest-of-django

TEMPLATES = [
    {
        'BACKEND': 'django.template.backends.django.DjangoTemplates',
        'APP_DIRS': False,
    },
]

settings.configure(TEMPLATES)




# Our template. Could just as easily be stored in a separate file
template = """
<html>
<head>
"""

"""
<title>Template {{ section title }}</title>
</head>
"""

"""
<body>
Body with {{ mystring }}.
{{%if%}}
</body>
"""

"""
</html>
"""

t = Template(template)
c = Context({"title": "title from code",
             "mystring":"string from code"})
print(t.render(c))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-8f46b302ed97> in <module>
#      28 """
#      29
# ---> 30 t = Template(template)
#      31 c = Context({"title": "title from code",
#      32              "mystring":"string from code"})
#
# ~/opt/anaconda3/lib/python3.8/site-packages/django/template/base.py in __init__(self, template_string, origin, name, engine)
#     145             from .engine import Engine
#     146
# --> 147             engine = Engine.get_default()
#     148         if origin is None:
#     149             origin = Origin(UNKNOWN_SOURCE)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/django/template/engine.py in get_default()
#     105         from django.template.backends.django import DjangoTemplates
#     106
# --> 107         for engine in engines.all():
#     108             if isinstance(engine, DjangoTemplates):
#     109                 return engine.engine
#
# ~/opt/anaconda3/lib/python3.8/site-packages/django/template/utils.py in all(self)
#      92
#      93     def all(self):
# ---> 94         return [self[alias] for alias in self]
#      95
#      96
#
# ~/opt/anaconda3/lib/python3.8/site-packages/django/template/utils.py in __iter__(self)
#      89
#      90     def __iter__(self):
# ---> 91         return iter(self.templates)
#      92
#      93     def all(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/django/utils/functional.py in __get__(self, instance, cls)
#      55         if instance is None:
#      56             return self
# ---> 57         res = instance.__dict__[self.name] = self.func(instance)
#      58         return res
#      59
#
# ~/opt/anaconda3/lib/python3.8/site-packages/django/template/utils.py in templates(self)
#      26     def templates(self):
#      27         if self._templates is None:
# ---> 28             self._templates = settings.TEMPLATES
#      29
#      30         templates = {}
#
# ~/opt/anaconda3/lib/python3.8/site-packages/django/conf/__init__.py in __getattr__(self, name)
#      92             self._setup(name)
#      93             _wrapped = self._wrapped
# ---> 94         val = getattr(_wrapped, name)
#      95
#      96         # Special case some settings which require further modification.
#
# ~/opt/anaconda3/lib/python3.8/site-packages/django/conf/__init__.py in __getattr__(self, name)
#     268         if not name.isupper() or name in self._deleted:
#     269             raise AttributeError
# --> 270         return getattr(self.default_settings, name)
#     271
#     272     def __setattr__(self, name, value):
#
# AttributeError: 'list' object has no attribute 'TEMPLATES'

# %% [markdown]
# ## Generate HTML

# %%
from lxml import etree

root = etree.Element('DOCUMENT')

type_node = etree.SubElement(root, 'TYPE')
type_node.text = 'EX-2.1'

div = etree.SubElement(type_node, 'sequence')
div.text = '2'

fname = etree.SubElement(div, 'filename')
fname.text = 'ex_219664.htm'

description = etree.SubElement(fname, 'description')
description.text = 'EXHIBIT 2.1'

text = etree.SubElement(description, 'text')

html = etree.SubElement(text, 'html')

head = etree.SubElement(html, 'head')

title = etree.SubElement(html, 'title')
title.text = 'ex_219664.htm'

body = etree.SubElement(html, 'body')

p1 = etree.SubElement(body, 'p')
p1_f = etree.SubElement(p1, 'font')
p1_b = etree.SubElement(p1_f, 'b')
p1_b.text = 'AGREEMENT AND PLAN OF MERGER'

p2 = etree.SubElement(body, 'p')
p2_f = etree.SubElement(p2, 'font')
p2_b = etree.SubElement(p2_f, 'b')
p2_b.text = 'by and among'



html_string = etree.tostring(root, pretty_print=True, method='html').decode('utf-8')

# %%
print(html_string)
# Out:
# <DOCUMENT><TYPE>EX-2.1<sequence>2<filename>ex_219664.htm<description>EXHIBIT 2.1<text><html>
# <head></head>
# <title>ex_219664.htm</title>
# <body>
# <p><font><b>AGREEMENT AND PLAN OF MERGER</b></font></p>
# <p><font><b>by and among</b></font></p>
# </body>
# </html></text></description></filename></sequence></TYPE></DOCUMENT>

# %%
feature_extractor = MarkupLMFeatureExtractor()
encoding = feature_extractor(html_string)

# %%
nodes = encoding['nodes'][0]
xpaths = encoding['xpaths'][0]

list(zip(nodes, xpaths))
# Out:
# [('EX-2.1', '/document/type'),
#  ('2', '/document/type/sequence'),
#  ('ex_219664.htm', '/document/type/sequence/filename'),
#  ('EXHIBIT 2.1', '/document/type/sequence/filename/description'),
#  ('ex_219664.htm',
#   '/document/type/sequence/filename/description/text/html/title'),
#  ('AGREEMENT AND PLAN OF MERGER',
#   '/document/type/sequence/filename/description/text/html/body/p[1]/font/b'),
#  ('by and among',
#   '/document/type/sequence/filename/description/text/html/body/p[2]/font/b')]

# %%
[('EX-2.1', '/document/type'),
 ('2', '/document/type/sequence'),
 ('ex_219664.htm', '/document/type/sequence/filename'),
 ('EXHIBIT 2.1', '/document/type/sequence/filename/description'),
 ('ex_219664.htm',
  '/document/type/sequence/filename/description/text/html/head/title'),
 ('Exhibit 2.1',
  '/document/type/sequence/filename/description/text/html/body/p[1]/font/b'),
 ('AGREEMENT AND PLAN OF MERGER',
  '/document/type/sequence/filename/description/text/html/body/p[3]/b'),
 ('by and among',
  '/document/type/sequence/filename/description/text/html/body/p[5]/b'),
 ('ALASKA COMMUNICATIONS SYSTEMS GROUP, INC.,',
  '/document/type/sequence/filename/description/text/html/body/p[7]/b'),
 ('PROJECT 8 BUYER, LLC,',
  '/document/type/sequence/filename/description/text/html/body/p[9]/b'),
 ('and',
  '/document/type/sequence/filename/description/text/html/body/p[11]/b'),
 ('PROJECT 8 MERGERSUB, INC.',
  '/document/type/sequence/filename/description/text/html/body/p[13]/b'),
 ('December 31, 2020',
  '/document/type/sequence/filename/description/text/html/body/p[15]/b'),
 ('TABLE OF CONTENTS',
  '/document/type/sequence/filename/description/text/html/body/p[18]/b'),
 ('Page',
  '/document/type/sequence/filename/description/text/html/body/table[1]/tr[1]/td[3]/b'),
 ('ARTICLE 1',
  '/document/type/sequence/filename/description/text/html/body/table[1]/tr[3]/td[1]/p/b'),
 ('DEFINITIONS',
  '/document/type/sequence/filename/description/text/html/body/table[1]/tr[3]/td[1]/p'),
 ('1',
  '/document/type/sequence/filename/description/text/html/body/table[1]/tr[3]/td[2]/p'),
 ('Section 1.01',
  '/document/type/sequence/filename/description/text/html/body/table[1]/tr[4]/td[1]/p'),
 ('Definitions',
  '/document/type/sequence/filename/description/text/html/body/table[1]/tr[4]/td[2]/p')]

# %%
tag_list = ['DOCUMENT', 'TYPE', 'SEQUENCE', 'filename', 'description', ]
node_list = []

# %%
class Ele(object):
    def __init__(self, tag_name, node_text, parent):
        self.tag_name = tag_name
        self.node_text = node_text
        self.parent = parent
        
    def get_root_tag(self):
        
        root_tag = self.parent
        if not root_tag:
            return self
        
        else:
            while root_tag.parent is not None:
                root_tag = self.parent.get_root_tag()
            
            return root_tag
        
    def add_to_tree(self):
        pass
    
    
    def __str__(self):
        return f"Ele(tag_name={self.tag_name}, node_text={self.node_text}, parent={self.parent})"
    
    def __repr__(self):
        return f"Ele(tag_name={self.tag_name}, node_text={self.node_text}, parent={self.parent})"

# %%
e1 = Ele('DOCUMENT', None, None)
e2 = Ele('TYPE', 'EX-2.1', e1)

# %%
e1
# Out:
# Ele(tag_name=DOCUMENT, node_text=None, parent=None)

# %%
e1.get_root_tag()
# Out:
# Ele(tag_name=DOCUMENT, node_text=None, parent=None)

# %%
e2
# Out:
# Ele(tag_name=TYPE, node_text=EX-2.1, parent=Ele(tag_name=DOCUMENT, node_text=None, parent=None))

# %%
e2.get_root_tag()

# %%
from yattag import Doc

# %%
doc, tag, text = Doc().tagtext()

# %%
with tag('DOCUMENT'):
    with tag('TYPE'):
        text('EX-2.1')
        with tag('sequence'):
            text('2')
            with tag('filename'):
                text('ex_219664.htm')
                with tag('description'):
                    text('EXHIBIT 2.1')

# %%
doc.getvalue()

# %% [raw]
# from contextlib import contextmanager

# %% [raw]
# @contextmanager
# def append_tag(tag_list, node_list, curr_pointer=None, ):
#     with tag(tag_list[curr_pointer]):
#         node_text = node_list[curr_pointer]
#
#         if isinstance(node_text, str):
#             text(node_list[curr_pointer])
#
#         while curr_pointer < len(tag_list):
#             curr_pointer += 1
#             append_tag(tag_list, curr_pointer)

# %% [raw]
# @contextmanager
# def append_tag(tag_name):
#         tag(tag_name)
# #         node_text = node_list[curr_pointer]
#
# #         if isinstance(node_text, str):
# #             text(node_list[curr_pointer])
#
# #         while curr_pointer < len(tag_list):
# #             curr_pointer += 1
# #             append_tag(tag_list, curr_pointer)

# %% [raw]
# with tag('Document'), tag('sequence'):
#     text('example')

# %% [raw]
# tag_list = ['document', 'type', 'sequence']
# node_list = [None, 'EX-2.1', '2']

# %%
feature_extractor2 = MarkupLMFeatureExtractor()
encoding2 = feature_extractor2(html_string)

# %%
encoding2

# %%
nodes, xpaths = encoding2['nodes'][0], encoding['xpaths'][0]

# %%
list(zip(nodes, xpaths))

# %%
processor2 = AutoProcessor.from_pretrained("microsoft/markuplm-base", truncation=True)
processor2.parse_html = True

encoding2 = processor2(html_string, return_tensors="pt")
encoding2

# %%
start_node_idx2 = 0
end_node_idx2 = 200

# %%
nodes2 = encoding2['nodes'][0][start_node_idx2: end_node_idx2]
xpaths2 = encoding2['xpaths'][0][start_node_idx2: end_node_idx2]
#xpaths = [x[49:] for x in xpaths]
# print("###################################################")
# print(xpaths)
# print("###################################################")
enc2 = processor(nodes=nodes2, xpaths=xpaths2, return_tensors="pt").to(device)
